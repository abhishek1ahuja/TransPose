# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import re
import numpy as np

# %%
log_results_csv_dir = "log/coco/transpose_r_chsel/jupyter/exp5"
exp5_filelist = list(filter(lambda x: x.endswith("csv"), os.listdir(log_results_csv_dir)))
exp5_filelist.sort()

# %%
log_results_exp7_csv_dir = "log/coco/transpose_r_mod/jupyter/exp7"
exp7_filelist = list(filter(lambda x: x.endswith("csv"), os.listdir(log_results_exp7_csv_dir)))
exp7_filelist.sort()

# %%
exp7_filelist
# Out:
# ['exp7_step1_finetune_2024-07-20-02-58_train_acc.csv',
#  'exp7_step1_finetune_2024-07-20-02-58_train_loss.csv',
#  'exp7_step1_finetune_2024-07-20-02-58_val_acc.csv',
#  'exp7_step1_finetune_2024-07-20-02-58_val_loss.csv']

# %%
def load_csv_files(log_dir, filelist, prefix, suffix, rounds):
    dfs = []
    for i in range(1, rounds + 1):
        # filepath_regex = os.path.join( f"{prefix}{i}{suffix}")
        filepath_regex =  f"{prefix}{i}{suffix}"
        filepath_regex = re.compile(filepath_regex)
        filename = list(filter(filepath_regex.match, filelist))[0]
        print(filename)
        filepath = os.path.join(log_dir, filename)
        if os.path.exists(filepath):
            dfs.append(pd.read_csv(filepath))
    return dfs

# %%
finetune_train_acc = load_csv_files(log_results_csv_dir, exp5_filelist, "exp5_step", "_finetune_.*_train_acc.csv", 16)
finetune_val_acc = load_csv_files(log_results_csv_dir, exp5_filelist, "exp5_step", "_finetune_.*_val_acc.csv", 16)
finetune_train_loss = load_csv_files(log_results_csv_dir, exp5_filelist, "exp5_step", "_finetune_.*_train_loss.csv", 16)
finetune_val_loss = load_csv_files(log_results_csv_dir, exp5_filelist, "exp5_step", "_finetune_.*_val_loss.csv", 16)
# Out:
# exp5_step1_finetune_2024-07-16-17-17_train_acc.csv
# exp5_step2_finetune_2024-07-16-18-37_train_acc.csv
# exp5_step3_finetune_2024-07-16-19-37_train_acc.csv
# exp5_step4_finetune_2024-07-16-20-57_train_acc.csv
# exp5_step5_finetune_2024-07-16-22-56_train_acc.csv
# exp5_step6_finetune_2024-07-17-00-04_train_acc.csv
# exp5_step7_finetune_2024-07-17-01-05_train_acc.csv
# exp5_step8_finetune_2024-07-17-02-06_train_acc.csv
# exp5_step9_finetune_2024-07-17-03-12_train_acc.csv
# exp5_step10_finetune_2024-07-17-09-39_train_acc.csv
# exp5_step11_finetune_2024-07-17-10-46_train_acc.csv
# exp5_step12_finetune_2024-07-17-12-17_train_acc.csv
# exp5_step13_finetune_2024-07-17-18-13_train_acc.csv
# exp5_step14_finetune_2024-07-18-02-01_train_acc.csv
# exp5_step15_finetune_2024-07-18-08-05_train_acc.csv
# exp5_step16_finetune_2024-07-18-09-23_train_acc.csv
# exp5_step1_finetune_2024-07-16-17-17_val_acc.csv
# exp5_step2_finetune_2024-07-16-18-37_val_acc.csv
# exp5_step3_finetune_2024-07-16-19-37_val_acc.csv
# exp5_step4_finetune_2024-07-16-20-57_val_acc.csv
# exp5_step5_finetune_2024-07-16-22-56_val_acc.csv
# exp5_step6_finetune_2024-07-17-00-04_val_acc.csv
# exp5_step7_finetune_2024-07-17-01-05_val_acc.csv
# exp5_step8_finetune_2024-07-17-02-06_val_acc.csv
# exp5_step9_finetune_2024-07-17-03-12_val_acc.csv
# exp5_step10_finetune_2024-07-17-09-39_val_acc.csv
# exp5_step11_finetune_2024-07-17-10-46_val_acc.csv
# exp5_step12_finetune_2024-07-17-12-17_val_acc.csv
# exp5_step13_finetune_2024-07-17-18-13_val_acc.csv
# exp5_step14_finetune_2024-07-18-02-01_val_acc.csv
# exp5_step15_finetune_2024-07-18-08-05_val_acc.csv
# exp5_step16_finetune_2024-07-18-09-23_val_acc.csv
# exp5_step1_finetune_2024-07-16-17-17_train_loss.csv
# exp5_step2_finetune_2024-07-16-18-37_train_loss.csv
# exp5_step3_finetune_2024-07-16-19-37_train_loss.csv
# exp5_step4_finetune_2024-07-16-20-57_train_loss.csv
# exp5_step5_finetune_2024-07-16-22-56_train_loss.csv
# exp5_step6_finetune_2024-07-17-00-04_train_loss.csv
# exp5_step7_finetune_2024-07-17-01-05_train_loss.csv
# exp5_step8_finetune_2024-07-17-02-06_train_loss.csv
# exp5_step9_finetune_2024-07-17-03-12_train_loss.csv
# exp5_step10_finetune_2024-07-17-09-39_train_loss.csv
# exp5_step11_finetune_2024-07-17-10-46_train_loss.csv
# exp5_step12_finetune_2024-07-17-12-17_train_loss.csv
# exp5_step13_finetune_2024-07-17-18-13_train_loss.csv
# exp5_step14_finetune_2024-07-18-02-01_train_loss.csv
# exp5_step15_finetune_2024-07-18-08-05_train_loss.csv
# exp5_step16_finetune_2024-07-18-09-23_train_loss.csv
# exp5_step1_finetune_2024-07-16-17-17_val_loss.csv
# exp5_step2_finetune_2024-07-16-18-37_val_loss.csv
# exp5_step3_finetune_2024-07-16-19-37_val_loss.csv
# exp5_step4_finetune_2024-07-16-20-57_val_loss.csv
# exp5_step5_finetune_2024-07-16-22-56_val_loss.csv
# exp5_step6_finetune_2024-07-17-00-04_val_loss.csv
# exp5_step7_finetune_2024-07-17-01-05_val_loss.csv
# exp5_step8_finetune_2024-07-17-02-06_val_loss.csv
# exp5_step9_finetune_2024-07-17-03-12_val_loss.csv
# exp5_step10_finetune_2024-07-17-09-39_val_loss.csv
# exp5_step11_finetune_2024-07-17-10-46_val_loss.csv
# exp5_step12_finetune_2024-07-17-12-17_val_loss.csv
# exp5_step13_finetune_2024-07-17-18-13_val_loss.csv
# exp5_step14_finetune_2024-07-18-02-01_val_loss.csv
# exp5_step15_finetune_2024-07-18-08-05_val_loss.csv
# exp5_step16_finetune_2024-07-18-09-23_val_loss.csv

# %%
exp7_finetune_train_acc = load_csv_files(log_results_exp7_csv_dir, exp7_filelist, "exp7_step", "_finetune_.*_train_acc.csv", 1)
exp7_finetune_val_acc = load_csv_files(log_results_exp7_csv_dir, exp7_filelist, "exp7_step", "_finetune_.*_val_acc.csv", 1)
exp7_finetune_train_loss = load_csv_files(log_results_exp7_csv_dir, exp7_filelist, "exp7_step", "_finetune_.*_train_loss.csv", 1)
exp7_finetune_val_loss = load_csv_files(log_results_exp7_csv_dir, exp7_filelist, "exp7_step", "_finetune_.*_val_loss.csv", 1)
# /media/abhishek/data/college/thesis/thesis_with_dr_duc/projects_github/TransPose/log/coco/transpose_r_mod/jupyter/exp7
# Out:
# exp7_step1_finetune_2024-07-20-02-58_train_acc.csv
# exp7_step1_finetune_2024-07-20-02-58_val_acc.csv
# exp7_step1_finetune_2024-07-20-02-58_train_loss.csv
# exp7_step1_finetune_2024-07-20-02-58_val_loss.csv

# %%
exp7_finetune_train_acc
# Out:
# [       Wall time  Step     Value
#  0   1.721437e+09     0  0.011253
#  1   1.721437e+09     1  0.079438
#  2   1.721437e+09     2  0.153650
#  3   1.721437e+09     3  0.128231
#  4   1.721437e+09     4  0.147180
#  ..           ...   ...       ...
#  79  1.721440e+09    79  0.458141
#  80  1.721440e+09    80  0.442146
#  81  1.721440e+09    81  0.374079
#  82  1.721440e+09    82  0.388785
#  83  1.721440e+09    83  0.396841
#
#  [84 rows x 3 columns]]

# %%
def plot_data(data_list, x_offset=12, y_offset=0, x_scale=1, y_scale=1, ax=None):
    if ax is None:
        ax = plt.gca()
    for i, data in enumerate(data_list):
        ax.plot((data['Step'] * x_scale ) + i * x_offset  , data['Value'] * y_scale)
    return ax
    

fig, axs = plt.subplots(2, 2, figsize=(10, 8))

plot_data(finetune_val_acc, ax=axs[0, 0])
axs[0, 0].set_title("Validation Accuracy")

plot_data(finetune_train_acc, x_scale=1/(84/12.0), x_offset=12, ax=axs[0, 1])
axs[0, 1].set_title("Train Accuracy")

plot_data(finetune_val_loss, x_offset=12, ax=axs[1, 0])
axs[1, 0].set_title("Validation Loss")

plot_data(finetune_train_loss, x_scale=1/(84/12.0), x_offset=12, ax=axs[1, 1])
axs[1, 1].set_title("Train Loss")

plt.tight_layout()

# %%
def plot_data(data_list, x_offset=12, y_offset=0, x_scale=1, y_scale=1, ax=None, c='c', label="l"):
    if ax is None:
        ax = plt.gca()
    for i, data in enumerate(data_list):
        ax.plot((data['Step'] * x_scale ) + i * x_offset  , data['Value'] * y_scale, color=c)
    return ax
    

fig, axs = plt.subplots(2, 1, figsize=(10, 8))

plot_data(finetune_train_acc, x_scale=1/(84/12.0), x_offset=12, ax=axs[0], c='m', label="training")
plot_data(finetune_val_acc, ax=axs[0], label="validation")
# axs[0].set_title("Validation Accuracy")
axs[0].set_title("Accuracy")
axs[0].plot(0,0,color='m',label="training")
axs[0].plot(0,0,color='c',label="validation")
axs[1].plot(0,0,color='m',label="training")
axs[1].plot(0,0,color='c',label="validation")

axs[0].legend()
plot_data(finetune_train_loss, x_scale=1/(84/12.0), x_offset=12, ax=axs[1], c='m', label="training")
plot_data(finetune_val_loss, x_offset=12, ax=axs[1], label="validation")
# axs[1].set_title("Validation Loss")


axs[1].set_title("Loss")
axs[1].legend()
fig.suptitle("Evaluation Metrics over 16 rounds of pruning and finetuning - strategy 2")
# plt.tight_layout()
# Out:
# Text(0.5, 0.98, 'Evaluation Metrics over 16 rounds of pruning and finetuning - strategy 2')

# %%
exp4_model_size_iter = [4735825, 4398782, 4158662, 4029203, 3932515, 3874012, 3832886]
exp4_model_acc_iter = [0.75, 0.713819, 0.501036, 0.495939, 0.467798,  0.476604, 0.493471]
exp4_sparsity = []
for i in range(len(exp4_model_size_iter)):
    exp4_sparsity.append(1 - exp4_model_size_iter[i] / exp4_model_size_iter[0])
exp4_conv_sparsity = []
model_part1_size = 1444928
for i in range(len(exp4_model_size_iter)):
    exp4_conv_sparsity.append(1 - (model_part1_size - (exp4_model_size_iter[0] - exp4_model_size_iter[i])) / model_part1_size)

# exp5_model_size_iter = [4735825, 4605918, 4476708, 4376520, 4295517, 4220238, 4147165, 4082626, 4028562, 3987670, 3958666, 3931900]
exp5_model_size_iter = [4735825, 4605918, 4476708, 4376520, 4295517, 4220238, 4147165, 4082626, 4028562, 3987670, 3958666, 3931900,3908419,3888909,3870814,3855166,3840072]
exp5_model_acc_iter = [0.75] + [data['Value'].iloc[-1] for data in finetune_val_acc]
exp5_sparsity = []
for i in range(len(exp5_model_size_iter)):
    exp5_sparsity.append(1 - exp5_model_size_iter[i] / exp5_model_size_iter[0])
    
exp5_conv_sparsity = []
model_part1_size = 1444928
for i in range(len(exp5_model_size_iter)):
    exp5_conv_sparsity.append(1 - (model_part1_size - (exp5_model_size_iter[0] - exp5_model_size_iter[i])) / model_part1_size)


fig, axs = plt.subplots()
axs.scatter(exp4_sparsity, exp4_model_acc_iter, label="strategy 1")
axs.plot(exp4_sparsity, exp4_model_acc_iter)
axs.scatter(exp5_sparsity, exp5_model_acc_iter, label="strategy 2")
axs.plot(exp5_sparsity, exp5_model_acc_iter)
axs.legend()
axs.set_ylabel("Validation Accuracy")
axs.set_xlabel("Sparsity")
axs.set_title("Performance vs Sparsity - strategy 1 and 2")
# Out:
# Text(0.5, 1.0, 'Performance vs Sparsity - strategy 1 and 2')

# %%
print("final sparsity ratio of exp5", (4735825 - 3840072)/4735825)
print("final sparsity ratio of exp4", (4735825 - 3832886)/4735825)
# Out:
# final sparsity ratio of exp5 0.18914402453637963
# final sparsity ratio of exp4 0.1906613947939377

# %%
fig, axs = plt.subplots()
axs.scatter(exp4_conv_sparsity, exp4_model_acc_iter)
axs.plot(exp4_conv_sparsity, exp4_model_acc_iter)
axs.scatter(exp5_conv_sparsity, exp5_model_acc_iter)
axs.plot(exp5_conv_sparsity, exp5_model_acc_iter)
axs.set_ylabel("Validation Accuracy")
axs.set_xlabel("Sparsity (only conv layers)")
# Out:
# Text(0.5, 0, 'Sparsity (only conv layers)')

# %%
# plot_data(finetune_train_acc[0])
fig, ax = plt.subplots()
x_scale = 1.0/7
x_offset = 1
y_scale = 1
c = 'c'
ax.plot((finetune_train_acc[0]['Step'] * x_scale ) + 0 * x_offset  , finetune_train_acc[0]['Value'] * y_scale, color=c)

# %%
# plot_data# plot_data(finetune_train_acc[0])
fig, ax = plt.subplots()
x_scale = 1.0/7
x_offset = 1
y_scale = 1
c = 'c'
ax.plot((exp7_finetune_train_acc['Step'] * x_scale ) + 0 * x_offset  , exp7_finetune_train_acc['Value'] * y_scale, color=c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 7
#       5 y_scale = 1
#       6 c = 'c'
# ----> 7 ax.plot((exp7_finetune_train_acc['Step'] * x_scale ) + 0 * x_offset  , exp7_finetune_train_acc['Value'] * y_scale, color=c)
#
# TypeError: list indices must be integers or slices, not str

# %%
exp7_finetune_train_acc
# Out:
# []

# %%
# prune_ignore_layers for step 5: [8, 51]
# prune_ignore_layers for step 6: [8, 51]
# prune_ignore_layers for step 7: [8, 20, 51]
# prune_ignore_layers for step 8: [8, 20, 51]
# prune_ignore_layers for step 9: [8, 20, 29, 51]
# prune_ignore_layers for step 10: [8, 20, 29, 51, 60, 69]

"""
Attempting to understand the impact of ignore prune layers
"""



nw_cfgs = np.asarray([
[64, 64, 64, 64, 64, 64, 128, 128, 128, 128, 128, 128, 128, 128],
[39, 46, 51, 63, 63, 64, 125, 128,  75, 124, 118, 128, 115, 128],
[35, 35, 44, 57, 58, 63, 121, 124,  50, 110, 106, 118,  96, 123],
[19, 35, 32, 57, 53, 63, 115, 124,  17, 110,  88, 118,  71, 123],
[ 8, 30, 18, 57, 42, 63, 108, 124,   8, 102,  68, 118,  54, 122],
[ 8, 24, 12, 54, 29, 60,  94, 120,   8,  91,  55, 115,  42, 119],
[ 8, 22,  8, 51, 18, 60,  76, 114,   8,  89,  38, 111,  32, 114],
[ 8, 20,  8, 50, 11, 60,  56, 108,   8,  83,  24, 106,  21, 113],
[ 8, 20,  8, 46,  6, 60,  42,  99,   8,  78,  11, 100,  13, 111],
[ 8, 18,  8, 43,  6, 59,  33,  94,   8,  69,   5,  89,   7, 104],
[8, 16,  8, 33,  6, 59,  27,  88,   8,  62,   5,  77,   7,  96],
[8, 15,  8, 27,  6, 58,  22,  79,   8,  52,   5,  68,   7,  91],
[8, 13,  8, 25,  6, 56,  22,  72,   8,  48,   5,  56,   7,  78],
[8, 12,  8, 18,  6, 52,  21,  67,   8,  43,   5,  49,   7,  70],
[8, 12,  8, 14,  6, 49,  20,  64,   8,  38,   5,  40,   7,  61],
[8, 11,  8, 10,  6, 46,  19,  60,   8,  29,   5,  32,   7,  61],
[8, 11,  8,  7,  6, 45,  18,  54,   8,  25,   5,  28,   7,  53]
    ])

# %%
plt.plot(np.sum(nw_cfgs, axis=1))

# %%
round_total = np.sum(nw_cfgs, axis=1)
plt.plot(-np.diff(round_total)/round_total[:-1])

# %%
round_total = np.sum(nw_cfgs, axis=1)
plt.plot(-np.diff(round_total)/round_total[:-1])
